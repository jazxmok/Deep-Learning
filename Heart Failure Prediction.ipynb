# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
import numpy as np

df=pd.read_csv(r'C:\Users\weije\Desktop\Kaggle Data\heart_failure_clinical_records_dataset.csv')
print(df.info())

class_counts = Counter(df['DEATH_EVENT'])
print('Classes and number of values in the dataset:', class_counts)

y = df["DEATH_EVENT"]
x= df[['age','anaemia','creatinine_phosphokinase','diabetes','ejection_fraction','high_blood_pressure','platelets','serum_creatinine','serum_sodium','sex','smoking','time']]

x  = pd.get_dummies(x)
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

ct = ColumnTransformer([("numeric", StandardScaler(), ['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time'])])
X_train = ct.fit_transform(X_train)
X_test = ct.transform(X_test)

le = LabelEncoder()
Y_train = le.fit_transform(Y_train.astype(str))
Y_test = le.transform(Y_test.astype(str))

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(12, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, epochs = 50, batch_size = 2, verbose=1)

loss, acc = model.evaluate(X_train, Y_train, verbose=0)
print("Loss", loss, "Accuracy:", acc)

y_hat = model.predict(X_test, verbose=0)
y_estimate = np.argmax(y_hat, axis=1)
y_true = np.argmax(Y_test, axis=1)
print(classification_report(y_true, y_estimate))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB
# None
# Classes and number of values in the dataset: Counter({0: 203, 1: 96})
# Epoch 1/50
# 105/105 [==============================] - 0s 912us/step - loss: 0.7115 - accuracy: 0.5407
# Epoch 2/50
# 105/105 [==============================] - 0s 881us/step - loss: 0.6327 - accuracy: 0.6507
# Epoch 3/50
# 105/105 [==============================] - 0s 958us/step - loss: 0.3235 - accuracy: 0.8565
# Epoch 29/50
# 105/105 [==============================] - 0s 934us/step - loss: 0.3211 - accuracy: 0.8565
# Epoch 30/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3198 - accuracy: 0.8517
# Epoch 31/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3189 - accuracy: 0.8517
# Epoch 32/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3181 - accuracy: 0.8565
# Epoch 33/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3157 - accuracy: 0.8612
# Epoch 34/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3149 - accuracy: 0.8565
# Epoch 35/50
# 105/105 [==============================] - 0s 968us/step - loss: 0.3147 - accuracy: 0.8517
# Epoch 36/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3131 - accuracy: 0.8565
# Epoch 37/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3111 - accuracy: 0.8565
# Epoch 38/50
# 105/105 [==============================] - 0s 958us/step - loss: 0.3099 - accuracy: 0.8517
# Epoch 39/50
# 105/105 [==============================] - 0s 926us/step - loss: 0.3099 - accuracy: 0.8565
# Epoch 40/50
# 105/105 [==============================] - 0s 912us/step - loss: 0.3084 - accuracy: 0.8469
# Epoch 41/50
# 105/105 [==============================] - 0s 910us/step - loss: 0.3063 - accuracy: 0.8612
# Epoch 42/50
# 105/105 [==============================] - 0s 932us/step - loss: 0.3071 - accuracy: 0.8565
# Epoch 43/50
# 105/105 [==============================] - 0s 878us/step - loss: 0.3058 - accuracy: 0.8612
# Epoch 44/50
# 105/105 [==============================] - 0s 899us/step - loss: 0.3043 - accuracy: 0.8517
# Epoch 45/50
# 105/105 [==============================] - 0s 898us/step - loss: 0.3045 - accuracy: 0.8612
# Epoch 46/50
# 105/105 [==============================] - 0s 928us/step - loss: 0.3030 - accuracy: 0.8565
# Epoch 47/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3030 - accuracy: 0.8565
# Epoch 48/50
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3031 - accuracy: 0.8565
# Epoch 49/50
# 105/105 [==============================] - 0s 919us/step - loss: 0.3003 - accuracy: 0.8565
# Epoch 50/50
# 105/105 [==============================] - 0s 926us/step - loss: 0.2986 - accuracy: 0.8565
# Loss 0.29327210783958435 Accuracy: 0.8564593195915222
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88        62
#            1       0.80      0.57      0.67        28
#
#     accuracy                           0.82        90
#    macro avg       0.81      0.75      0.77        90
# weighted avg       0.82      0.82      0.81        90
